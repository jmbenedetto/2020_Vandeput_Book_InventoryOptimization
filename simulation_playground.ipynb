# %% [markdown]
# # GOAL

# %% [markdown]
# # MODEL DESCRIPTION

# %% [markdown]
# # PACKAGES

# %%
import salabim as sim
import math
from scipy.stats import norm

# %% [markdown]
# # FIXED PARAMETERS

# %%
env = sim.Environment(trace=True)

# define replenishment parameters
param_lead_time = 5
param_order_frequency = 3
param_order_rounding = 5
param_safety_service_level = 0.95

planning_horizon = param_order_frequency + param_lead_time
# Out:
# line#        time current component    action                               information
# ------ ---------- -------------------- -----------------------------------  ------------------------------------------------
#                                        line numbers refers to               1013671131.py
#     1                                  default environment initialize
#     1                                  main create
#     1       0.000 main                 current

# %% [markdown]
# # DISTRIBUTIONS

# %%
# define functions
function_demand = sim.Bounded(
    sim.Normal(mean=1, standard_deviation=2), lowerbound=0, upperbound=10
)
function_forecast = sim.Bounded(
    sim.Normal(mean=20, standard_deviation=20), lowerbound=0, upperbound=120
)
function_lead_time = sim.Bounded(
    sim.Normal(mean=5, standard_deviation=2), lowerbound=0, upperbound=10
)
function_delivery_fullfillment = sim.Bounded(
    sim.Normal(mean=0.75, standard_deviation=0.15), lowerbound=0, upperbound=1
)

# %% [markdown]
# # MONITORS

# %%
initial_inventory = 100
initial_open_po = 0

monitor_demand = sim.Monitor(name="demand", type="float")
monitor_inventory = sim.Monitor(
    name="inventory", level=True, initial_tally=initial_inventory, type="float"
)
monitor_po = sim.Monitor(name="po", type="float")
monitor_open_po = sim.Monitor(
    name="open_po", level=True, initial_tally=initial_open_po, type="float"
)
monitor_lost_sales = sim.Monitor(name="lost_sales", type="float")

# %% [markdown]
# # Animation

# %%
sim.AnimateText("Demonstration dynamic AnimateMonitor", fontsize=20, y=700, x=100)

sim.AnimateMonitor(
    monitor_inventory,
    linewidth=3,
    x=100,
    y=100,
    width=900,
    height=250,
    vertical_scale=lambda arg, t: min(50, 250 / arg.monitor().maximum()),
    labels=lambda arg, t: [i for i in range(0, int(arg.monitor().maximum()), 10)],
    horizontal_scale=lambda t: min(10, 900 / t),
)

# sim.AnimateMonitor(
#     monitor_inventory,
#     linewidth=5,
#     x=100,
#     y=600,
#     width=900,
#     height=100,
#     vertical_scale=lambda arg, t: min(50, 250 / arg.monitor().maximum()),
#     labels=lambda arg, t: [i for i in range(0, int(arg.monitor().maximum()), 10)],
#     horizontal_scale=lambda t: min(10, 900 / t),
# )

# sim.AnimateMonitor(
#     monitor_demand,
#     linewidth=5,
#     x=100,
#     y=300,
#     width=900,
#     height=100,
#     vertical_scale=lambda arg, t: min(50, 250 / arg.monitor().maximum()),
#     labels=lambda arg, t: [i for i in range(0, int(arg.monitor().maximum()), 10)],
#     horizontal_scale=lambda t: min((10, 900 / t)),
# )

# %% [markdown]
# # CLASSES

# %%
class Sales(sim.Component):
    def process(self):
        while True:
            print("start of period inventory: ", monitor_inventory.get())
            demand = function_demand.sample()
            monitor_demand.tally(demand)
            print("daily demand: ", demand)
            monitor_lost_sales.tally(max(0, demand - monitor_inventory.get()))
            monitor_inventory.tally(max(0, monitor_inventory.get() - demand))
            print("end of period inventory: ", monitor_inventory.get())
            self.hold(1)

# %% [markdown]
# # FUNCTIONS

# %%
def calculate_safety_stock(
    avg_demand, std_demand, avg_lead_time, std_lead_time, service_level
):
    # Calculate the Z-score for the desired service level
    z_score = norm.ppf(service_level)

    # Calculate the safety stock
    safety_stock = z_score * math.sqrt(
        (avg_lead_time * std_demand**2) + (avg_demand**2 * std_lead_time**2)
    )
    return safety_stock

# %% [markdown]
# # RUN

# %%
# env.speed(10)
Sales()

# env.video_repeat(0)
# env.video("demo dynamic animatemonitor.gif")
# env.run(1)
# env.animate(True)
env.run(200)
# env.video_close()
# Out:
#                                        line numbers prefixed by A refer to  2336438899.py
#    A2                                  sales.1 create
#                                        line numbers prefixed by B refer to  2873576339.py
#    A2                                  sales.1 activate                     scheduled for 0.000 @   B2+ process=process
#    A8                                  main run +200.000                    scheduled for 200.000 @    8+
#    B2+      0.000 sales.1              current
# start of period inventory:  100
# daily demand:  1.3615418191191784
# end of period inventory:  98.63845818088082
#   B11                                  sales.1 hold +1.000                  scheduled for 1.000 @  B11+
#   B11+      1.000 sales.1              current
# start of period inventory:  98.63845818088082
# daily demand:  2.664511610622426
# end of period inventory:  95.97394657025839
#   B11                                  sales.1 hold +1.000                  scheduled for 2.000 @  B11+
#   B11+      2.000 sales.1              current
# start of period inventory:  95.97394657025839
# daily demand:  2.3576589332425204
# end of period inventory:  93.61628763701587
#   B11                                  sales.1 hold +1.000                  scheduled for 3.000 @  B11+
#   B11+      3.000 sales.1              current
# start of period inventory:  93.61628763701587
# daily demand:  2.378057956475783
# end of period inventory:  91.23822968054009
#   B11                                  sales.1 hold +1.000                  scheduled for 4.000 @  B11+
#   B11+      4.000 sales.1              current
# start of period inventory:  91.23822968054009
# daily demand:  0.5718368191645369
# end of period inventory:  90.66639286137556
#   B11                                  sales.1 hold +1.000                  scheduled for 5.000 @  B11+
#   B11+      5.000 sales.1              current
# start of period inventory:  90.66639286137556
# daily demand:  3.900979445864239
# end of period inventory:  86.76541341551132
#   B11                                  sales.1 hold +1.000                  scheduled for 6.000 @  B11+
#   B11+      6.000 sales.1              current
# start of period inventory:  86.76541341551132
# daily demand:  0.2555147303486831
# end of period inventory:  86.50989868516264
#   B11                                  sales.1 hold +1.000                  scheduled for 7.000 @  B11+
#   B11+      7.000 sales.1              current
# start of period inventory:  86.50989868516264
# daily demand:  2.7470906860468336
# end of period inventory:  83.76280799911581
#   B11                                  sales.1 hold +1.000                  scheduled for 8.000 @  B11+
#   B11+      8.000 sales.1              current
# start of period inventory:  83.76280799911581
# daily demand:  2.0312756786460957
# end of period inventory:  81.73153232046971
#   B11                                  sales.1 hold +1.000                  scheduled for 9.000 @  B11+
#   B11+      9.000 sales.1              current
# start of period inventory:  81.73153232046971
# daily demand:  1.0647932943794765
# end of period inventory:  80.66673902609024
#   B11                                  sales.1 hold +1.000                  scheduled for 10.000 @  B11+
#   B11+     10.000 sales.1              current
# start of period inventory:  80.66673902609024
# daily demand:  3.9122433225769484
# end of period inventory:  76.7544957035133
#   B11                                  sales.1 hold +1.000                  scheduled for 11.000 @  B11+
#   B11+     11.000 sales.1              current
# start of period inventory:  76.7544957035133
# daily demand:  0.886169244133973
# end of period inventory:  75.86832645937933
#   B11                                  sales.1 hold +1.000                  scheduled for 12.000 @  B11+
#   B11+     12.000 sales.1              current
# start of period inventory:  75.86832645937933
# daily demand:  0.2446497236833889
# end of period inventory:  75.62367673569594
#   B11                                  sales.1 hold +1.000                  scheduled for 13.000 @  B11+
#   B11+     13.000 sales.1              current
# start of period inventory:  75.62367673569594
# daily demand:  1.3023832235853
# end of period inventory:  74.32129351211064
#   B11                                  sales.1 hold +1.000                  scheduled for 14.000 @  B11+
#   B11+     14.000 sales.1              current
# start of period inventory:  74.32129351211064
# daily demand:  0.8217294848846526
# end of period inventory:  73.49956402722599
#   B11                                  sales.1 hold +1.000                  scheduled for 15.000 @  B11+
#   B11+     15.000 sales.1              current
# start of period inventory:  73.49956402722599
# daily demand:  0.7385294103782231
# end of period inventory:  72.76103461684777
#   B11                                  sales.1 hold +1.000                  scheduled for 16.000 @  B11+
#   B11+     16.000 sales.1              current
# start of period inventory:  72.76103461684777
# daily demand:  1.0184110029468942
# end of period inventory:  71.74262361390088
#   B11                                  sales.1 hold +1.000                  scheduled for 17.000 @  B11+
#   B11+     17.000 sales.1              current
# start of period inventory:  71.74262361390088
# daily demand:  5.370155178384188
# end of period inventory:  66.37246843551668
#   B11                                  sales.1 hold +1.000                  scheduled for 18.000 @  B11+
#   B11+     18.000 sales.1              current
# start of period inventory:  66.37246843551668
# daily demand:  1.2957627938363099
# end of period inventory:  65.07670564168038
#   B11                                  sales.1 hold +1.000                  scheduled for 19.000 @  B11+
#   B11+     19.000 sales.1              current
# start of period inventory:  65.07670564168038
# daily demand:  6.487586306026259
# end of period inventory:  58.58911933565412
#   B11                                  sales.1 hold +1.000                  scheduled for 20.000 @  B11+
#   B11+     20.000 sales.1              current
# start of period inventory:  58.58911933565412
# daily demand:  0.2843487517458968
# end of period inventory:  58.30477058390822
#   B11                                  sales.1 hold +1.000                  scheduled for 21.000 @  B11+
#   B11+     21.000 sales.1              current
# start of period inventory:  58.30477058390822
# daily demand:  0.09205848595033583
# end of period inventory:  58.21271209795788
#   B11                                  sales.1 hold +1.000                  scheduled for 22.000 @  B11+
#   B11+     22.000 sales.1              current
# start of period inventory:  58.21271209795788
# daily demand:  0.2968787065287689
# end of period inventory:  57.91583339142912
#   B11                                  sales.1 hold +1.000                  scheduled for 23.000 @  B11+
#   B11+     23.000 sales.1              current
# start of period inventory:  57.91583339142912
# daily demand:  1.7960672743479975
# end of period inventory:  56.11976611708112
#   B11                                  sales.1 hold +1.000                  scheduled for 24.000 @  B11+
#   B11+     24.000 sales.1              current
# start of period inventory:  56.11976611708112
# daily demand:  1.6904036494906944
# end of period inventory:  54.42936246759042
#   B11                                  sales.1 hold +1.000                  scheduled for 25.000 @  B11+
#   B11+     25.000 sales.1              current
# start of period inventory:  54.42936246759042
# daily demand:  2.1047750473535265
# end of period inventory:  52.324587420236895
#   B11                                  sales.1 hold +1.000                  scheduled for 26.000 @  B11+
#   B11+     26.000 sales.1              current
# start of period inventory:  52.324587420236895
# daily demand:  4.290513456062461
# end of period inventory:  48.03407396417443
#   B11                                  sales.1 hold +1.000                  scheduled for 27.000 @  B11+
#   B11+     27.000 sales.1              current
# start of period inventory:  48.03407396417443
# daily demand:  2.4412617155864895
# end of period inventory:  45.59281224858794
#   B11                                  sales.1 hold +1.000                  scheduled for 28.000 @  B11+
#   B11+     28.000 sales.1              current
# start of period inventory:  45.59281224858794
# daily demand:  0.7899919891892584
# end of period inventory:  44.80282025939868
#   B11                                  sales.1 hold +1.000                  scheduled for 29.000 @  B11+
#   B11+     29.000 sales.1              current
# start of period inventory:  44.80282025939868
# daily demand:  2.391202040023991
# end of period inventory:  42.41161821937469
#   B11                                  sales.1 hold +1.000                  scheduled for 30.000 @  B11+
#   B11+     30.000 sales.1              current
# start of period inventory:  42.41161821937469
# daily demand:  5.516151797225087
# end of period inventory:  36.8954664221496
#   B11                                  sales.1 hold +1.000                  scheduled for 31.000 @  B11+
#   B11+     31.000 sales.1              current
# start of period inventory:  36.8954664221496
# daily demand:  0.7441070397764828
# end of period inventory:  36.15135938237312
#   B11                                  sales.1 hold +1.000                  scheduled for 32.000 @  B11+
#   B11+     32.000 sales.1              current
# start of period inventory:  36.15135938237312
# daily demand:  2.213686873803873
# end of period inventory:  33.93767250856925
#   B11                                  sales.1 hold +1.000                  scheduled for 33.000 @  B11+
#   B11+     33.000 sales.1              current
# start of period inventory:  33.93767250856925
# daily demand:  2.5834560184394193
# end of period inventory:  31.35421649012983
#   B11                                  sales.1 hold +1.000                  scheduled for 34.000 @  B11+
#   B11+     34.000 sales.1              current
# start of period inventory:  31.35421649012983
# daily demand:  3.260115476570785
# end of period inventory:  28.094101013559044
#   B11                                  sales.1 hold +1.000                  scheduled for 35.000 @  B11+
#   B11+     35.000 sales.1              current
# start of period inventory:  28.094101013559044
# daily demand:  0.6070222064115686
# end of period inventory:  27.487078807147476
#   B11                                  sales.1 hold +1.000                  scheduled for 36.000 @  B11+
#   B11+     36.000 sales.1              current
# start of period inventory:  27.487078807147476
# daily demand:  0.04887698856698797
# end of period inventory:  27.438201818580488
#   B11                                  sales.1 hold +1.000                  scheduled for 37.000 @  B11+
#   B11+     37.000 sales.1              current
# start of period inventory:  27.438201818580488
# daily demand:  0.7805464563985188
# end of period inventory:  26.65765536218197
#   B11                                  sales.1 hold +1.000                  scheduled for 38.000 @  B11+
#   B11+     38.000 sales.1              current
# start of period inventory:  26.65765536218197
# daily demand:  3.3901245881358846
# end of period inventory:  23.267530774046087
#   B11                                  sales.1 hold +1.000                  scheduled for 39.000 @  B11+
#   B11+     39.000 sales.1              current
# start of period inventory:  23.267530774046087
# daily demand:  0.30262375116577955
# end of period inventory:  22.964907022880308
#   B11                                  sales.1 hold +1.000                  scheduled for 40.000 @  B11+
#   B11+     40.000 sales.1              current
# start of period inventory:  22.964907022880308
# daily demand:  0.4164682747945814
# end of period inventory:  22.548438748085726
#   B11                                  sales.1 hold +1.000                  scheduled for 41.000 @  B11+
#   B11+     41.000 sales.1              current
# start of period inventory:  22.548438748085726
# daily demand:  2.2854719406627613
# end of period inventory:  20.262966807422963
#   B11                                  sales.1 hold +1.000                  scheduled for 42.000 @  B11+
#   B11+     42.000 sales.1              current
# start of period inventory:  20.262966807422963
# daily demand:  3.8275284987619216
# end of period inventory:  16.43543830866104
#   B11                                  sales.1 hold +1.000                  scheduled for 43.000 @  B11+
#   B11+     43.000 sales.1              current
# start of period inventory:  16.43543830866104
# daily demand:  3.303940584288717
# end of period inventory:  13.131497724372323
#   B11                                  sales.1 hold +1.000                  scheduled for 44.000 @  B11+
#   B11+     44.000 sales.1              current
# start of period inventory:  13.131497724372323
# daily demand:  4.606929115385904
# end of period inventory:  8.524568608986419
#   B11                                  sales.1 hold +1.000                  scheduled for 45.000 @  B11+
#   B11+     45.000 sales.1              current
# start of period inventory:  8.524568608986419
# daily demand:  0.42010737651723273
# end of period inventory:  8.104461232469186
#   B11                                  sales.1 hold +1.000                  scheduled for 46.000 @  B11+
#   B11+     46.000 sales.1              current
# start of period inventory:  8.104461232469186
# daily demand:  1.1122371129030713
# end of period inventory:  6.992224119566115
#   B11                                  sales.1 hold +1.000                  scheduled for 47.000 @  B11+
#   B11+     47.000 sales.1              current
# start of period inventory:  6.992224119566115
# daily demand:  0.5256405462223052
# end of period inventory:  6.46658357334381
#   B11                                  sales.1 hold +1.000                  scheduled for 48.000 @  B11+
#   B11+     48.000 sales.1              current
# start of period inventory:  6.46658357334381
# daily demand:  2.4822684507340878
# end of period inventory:  3.984315122609722
#   B11                                  sales.1 hold +1.000                  scheduled for 49.000 @  B11+
#   B11+     49.000 sales.1              current
# start of period inventory:  3.984315122609722
# daily demand:  2.8271385491600114
# end of period inventory:  1.1571765734497106
#   B11                                  sales.1 hold +1.000                  scheduled for 50.000 @  B11+
#   B11+     50.000 sales.1              current
# start of period inventory:  1.1571765734497106
# daily demand:  0.5336474420343362
# end of period inventory:  0.6235291314153744
#   B11                                  sales.1 hold +1.000                  scheduled for 51.000 @  B11+
#   B11+     51.000 sales.1              current
# start of period inventory:  0.6235291314153744
# daily demand:  0.5441865614808037
# end of period inventory:  0.07934256993457067
#   B11                                  sales.1 hold +1.000                  scheduled for 52.000 @  B11+
#   B11+     52.000 sales.1              current
# start of period inventory:  0.07934256993457067
# daily demand:  0.40671133335723464
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for
000 sales.1              current
# start of period inventory:  0
# daily demand:  0.5953507371157312
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 181.000 @  B11+
#   B11+    181.000 sales.1              current
# start of period inventory:  0
# daily demand:  4.077468816513262
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 182.000 @  B11+
#   B11+    182.000 sales.1              current
# start of period inventory:  0
# daily demand:  2.892260150367909
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 183.000 @  B11+
#   B11+    183.000 sales.1              current
# start of period inventory:  0
# daily demand:  4.2544431919632695
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 184.000 @  B11+
#   B11+    184.000 sales.1              current
# start of period inventory:  0
# daily demand:  2.563235082579462
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 185.000 @  B11+
#   B11+    185.000 sales.1              current
# start of period inventory:  0
# daily demand:  2.272798041187671
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 186.000 @  B11+
#   B11+    186.000 sales.1              current
# start of period inventory:  0
# daily demand:  1.7828367017128741
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 187.000 @  B11+
#   B11+    187.000 sales.1              current
# start of period inventory:  0
# daily demand:  3.229221215190095
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 188.000 @  B11+
#   B11+    188.000 sales.1              current
# start of period inventory:  0
# daily demand:  1.8530121838659692
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 189.000 @  B11+
#   B11+    189.000 sales.1              current
# start of period inventory:  0
# daily demand:  0.42493982027086274
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 190.000 @  B11+
#   B11+    190.000 sales.1              current
# start of period inventory:  0
# daily demand:  1.8105056245089837
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 191.000 @  B11+
#   B11+    191.000 sales.1              current
# start of period inventory:  0
# daily demand:  1.0362084429015581
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 192.000 @  B11+
#   B11+    192.000 sales.1              current
# start of period inventory:  0
# daily demand:  0.2638715584061836
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 193.000 @  B11+
#   B11+    193.000 sales.1              current
# start of period inventory:  0
# daily demand:  2.2040809114116238
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 194.000 @  B11+
#   B11+    194.000 sales.1              current
# start of period inventory:  0
# daily demand:  0.6222792000867261
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 195.000 @  B11+
#   B11+    195.000 sales.1              current
# start of period inventory:  0
# daily demand:  3.522805389104178
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 196.000 @  B11+
#   B11+    196.000 sales.1              current
# start of period inventory:  0
# daily demand:  3.0060003985270605
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 197.000 @  B11+
#   B11+    197.000 sales.1              current
# start of period inventory:  0
# daily demand:  1.0114794180239395
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 198.000 @  B11+
#   B11+    198.000 sales.1              current
# start of period inventory:  0
# daily demand:  2.3739817449348983
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 199.000 @  B11+
#   B11+    199.000 sales.1              current
# start of period inventory:  0
# daily demand:  0.3387359242412348
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 200.000 @  B11+
#   B11+    200.000 sales.1              current
# start of period inventory:  0
# daily demand:  0.19465402026528755
# end of period inventory:  0
#   B11                                  sales.1 hold +1.000                  scheduled for 201.000 @  B11+
#     8+    200.000 main                 current

# %%
print("monitor_inventory", monitor_inventory.as_dataframe())
print("monitor_demand", monitor_demand.as_dataframe())
print("monitor_lost_sales", monitor_lost_sales.as_dataframe())
# Out:
# monitor_inventory          t  inventory.x
# 0      0.0    98.638458
# 1      1.0    95.973947
# 2      2.0    93.616288
# 3      3.0    91.238230
# 4      4.0    90.666393
# ..     ...          ...
# 196  196.0     0.000000
# 197  197.0     0.000000
# 198  198.0     0.000000
# 199  199.0     0.000000
# 200  200.0     0.000000
#
# [201 rows x 2 columns]
# monitor_demand          t  demand.x
# 0      0.0  1.361542
# 1      1.0  2.664512
# 2      2.0  2.357659
# 3      3.0  2.378058
# 4      4.0  0.571837
# ..     ...       ...
# 196  196.0  3.006000
# 197  197.0  1.011479
# 198  198.0  2.373982
# 199  199.0  0.338736
# 200  200.0  0.194654
#
# [201 rows x 2 columns]
# monitor_lost_sales          t  lost_sales.x
# 0      0.0      0.000000
# 1      1.0      0.000000
# 2      2.0      0.000000
# 3      3.0      0.000000
# 4      4.0      0.000000
# ..     ...           ...
# 196  196.0      3.006000
# 197  197.0      1.011479
# 198  198.0      2.373982
# 199  199.0      0.338736
# 200  200.0      0.194654
#
# [201 rows x 2 columns]
